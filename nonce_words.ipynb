# %%
import pandas as pd
import numpy as np
# Read dataframe
df = pd.read_csv('malayalam_aligned.tsv', sep='\t', encoding='utf-8')
df.shape, df.columns, df['sentID'].unique().shape
# Out:
# /home/ashim/indicmt/env_mt/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ((98420, 29),
#  Index(['Unnamed: 0', 'Unnamed: 0.1', 'sentID', 'wordPosition', 'word', 'lemma',
#         'UPOS', 'XPOS', 'FEATS', 'HEAD', 'DEPREL', 'DEPS', 'MISC', 'category',
#         'gender', 'number', 'person', 'case', 'vib', 'tam', 'source', 'target',
#         'common', 'deleted', 'sourceSkeleton', 'targetSkeleton', 'added',
#         'aligned', 'extracted'],
#        dtype='object'),
#  (11651,))

# %%
sentToremove = df[df['vib'].isnull()]['sentID'].unique()
df = df[~(df['sentID'].isin(sentToremove))]
df.shape, df['sentID'].unique().shape
# Out:
# ((97050, 29), (11521,))

# %%
# Remove sentences with null vib value
cl = ['Unnamed: 0', 'sentID', 'word', 'lemma', 'DEPS', 'vib']
lemma_dep_group_by = df[cl].groupby(['lemma', 'DEPS'])
lemma_group_by = df[cl].groupby('lemma')

# %%
df.index

# %%
# For a lemma and dep value, find its possible nonce vib values
# First get a set of vibs co-occurring with a (lemma, dep) : lemma_dep_to_vib = {}
# Then get a set of all vibs co-occurring with a lemma : lemma_to_vib = {}

lemma_dep_to_vib = {}
lemma_to_vib = {}

def get_possible_replacements(lemma, dep, lemma_dep_group_by, lemma_group_by):
    
    lp_set = set(list(lemma_dep_group_by.get_group((lemma, dep))['vib']))
    
    l_set = set(list(lemma_group_by.get_group((lemma))['vib']))
    
    possible_vibs = l_set - lp_set
    possible_vibs = possible_vibs - set(['SAME'])
    return possible_vibs

for name, group in lemma_dep_group_by:
    lemma_dep_to_vib[name] = get_possible_replacements(name[0], name[1], lemma_dep_group_by, lemma_group_by)
# print(lemma_dep_to_vib)

# %%
deps_to_include = ['k1', 'k2', 'k3', 'k4', 'k5', 'r6', 'k7', 'vmod', 'nmod']
count = 0
for key, val in lemma_dep_to_vib.items():
    if len(val) > 40 and key[1] in set(deps_to_include):
        print(key)
        print(val)
        count +=1
print(count)
lemma_vib_group_by = df[cl].groupby(['lemma', 'vib'])
sentID_group_obj = df.groupby('sentID')
sent_ids = list(sentID_group_obj.groups.keys())
# Out:
# ('ആ', 'k1')
# {'ഇഇട്ട്', 'എ', 'ഇന്', 'അ', 'ഇതീര്ഉന്നു', 'ഇതീര്ന്ന', 'ഇതിര്ഉന്നു', 'ആയതിനാല്\u200d', 'ഇരി', 'ഇരി!ഉന്നു', 'ആയില്ല', 'ആഇരിഉം', 'ഇഇരിഉന്നു', 'ആയാല്\u200d', 'അഏപ്പോള്ഏക്ക്', 'ഇഇരിഉന്ന', 'ഇഇരിക്കണം', 'ഇഇരിക്ക്ഉം', 'ഇഇരിഉന്ന്ഇല്ല', 'ഇട്ട്', 'ഉന്നു', 'ഇതീര്ഉന്ന', 'ഇഇര്ഉന്ന്', 'ഇവര്ഉന്നു', 'അത്ഓടെ', 'ഇ', 'ഇഇരിഉം', 'ആയപ്പോള്\u200d', 'ഇഇരിഏണ്ട', 'ഇരിക്ക്ആം', '�
# ('എത്ത്', 'k7')
# {'ഇച്ചത്ഉ്', 'ഇഇട്ട്', 'ഉമ്പോള്', 'ഉന്നഅര്ഇല്', 'ഇഇച്ച്ഇട്ട്ഉണ്ട്', 'ഇനില്ഉന്നു', 'ആറ്ഉണ്ട്', 'ുക', 'ഇഉം', 'ആണ്', 'ആറ്ഉണ്ട്ആഇരിഉന്നു', 'ഇഇരിഉന്നു', 'ഇഇര്ഉന്നു', 'ഇകഴിഞ്ഞു', 'ുമ്പോള്\u200d', 'ഉന്ന', 'ഇകഴിഉന്ന', 'ഇഇട്ട്ഇല്ല', 'ാന്', 'ആറ്', 'ഉന്നഉ്', 'ഉന്നു', 'ഇഉന്ന', 'ഇചേര്ഉന്ന', 'ുമ്പോള്\u200d', 'ാന്\u200d', 'ഉന്നഓടെ', 'ഇ', 'ഉന്വോള്\u200d', 'ഉന്നഅര്', 'ഉന്നഅര്ഉടെ', 'ഉന്നത്ഉ്', 'ഏണ്ട', 'ഇഉ്', 'ുമ്പോഴേക്കും', 'ിയത്', 'ഇചേര്ഉന്നഅറ്ക്ക്', 'അണം', 'ഇഇച്ച്ഇരിഉന്ന', 'ഉം', 'ആം', 'ഉക', 'ഇആം'}
# ('കഴി', 'k1')
# {'ഞ്ഞാല്\u200d', 'ക്കുന്പോള്\u200d\u200d', 'യാതെ', 'ച്ച', 'യും', 'യുക', 'ഞ്ഞുആല്', 'ഞ്ഞുഇരിഉന്നു', 'ഉ്', 'ആറ്ഉണ്ട്', 'ഞ്ഞുപോഇഇരിഉന്നു', 'ഞ്ഞ്ഉള്', 'ഇരിഉന്ന', 'ക്കാന്\u200d', 'ഊ', 'ഇരിഉന്നു', 'ഉന്ന', 'ച്ചുഇട്ട്', 'യൂ', 'ഞ്ഞുഏയ്ക്കാം', 'ഉന്നഉ്', 'ഉന്നു', 'ച്ചു', 'യാന്\u200d', '\u200dഞ്ഞ', 'ഉന്നഓടെ', 'യുമ്പോള്\u200d', 'ഉന്നുഉണ്ട്', 'ഞ്ഞപ്പോള്', 'ഉന്നഅര്', 'ഏണ്ട', 'ഞ്ഞ്', 'ആവുന്ന', 'യാത്ത', 'ച്ച്', 'ക്കാന്', 'പ്രോത്സാഹിപ്പിക്കാന്\u200d', 'ച്ചുഇരിഉന്നു', 'അണം', 'ഞ്ഞഇട്ട്', 'അട്ടെ', 'യുകയില്ല', 'ക്കുക', 'ആം'}
# ('കഴി', 'k2')
# {'ഞ്ഞാല്\u200d', 'ഉം', 'ക്കുന്പോള്\u200d\u200d', 'യാതെ', 'ച്ച', 'യും', 'യുക', 'ഞ്ഞുആല്', 'ഞ്ഞുഇരിഉന്നു', 'ഉ്', 'ആറ്ഉണ്ട്', 'ഞ്ഞു', 'ഞ്ഞുപോഇഇരിഉന്നു', 'ഞ്ഞ്ഉള്', 'ഇരിഉന്ന', 'ക്കാന്\u200d', 'ഇല്ല', 'ഊ', 'ഇരിഉന്നു', 'ഉന്ന', 'ച്ചുഇട്ട്', 'ഞ്ഞ', 'ഞ്ഞുഏയ്ക്കാം', 'യൂ', 'ഉന്നഉ്', 'ഉന്നു', 'ച്ചു', 'യാന്\u200d', 'ഉന്നഓടെ', 'യുമ്പോള്\u200d', 'ഉന്നുഉണ്ട്', 'ഞ്ഞപ്പോള്', 'ഉന്നഅര്', 'ഏണ്ട', 'ഞ്ഞ്', 'ആവുന്ന', 'യാത്ത', 'ച്ച്', 'ക്കാന്', 'പ്രോത്സാഹിപ്പിക്കാന്\u200d', 'ച്ചുഇരിഉന്നു', 'അണം', 'ഞ്ഞഇട്ട്', 'അട്ടെ', 'യുകയില്ല', 'ക്കുക', 'ആം'}
# ('കഴി', 'k7')
# {'ഞ്ഞാല്\u200d', 'ഉം', 'ക്കുന്പോള്\u200d\u200d', 'യാതെ', 'ച്ച', 'യും', 'യുക', 'ഞ്ഞുആല്', 'ഞ്ഞുഇരിഉന്നു', 'ഉ്', 'ആറ്ഉണ്ട്', 'ഞ്ഞു', 'ഞ്ഞുപോഇഇരിഉന്നു', 'ഞ്ഞ്ഉള്', 'ഇരിഉന്ന', 'ക്കാന്\u200d', 'ഇല്ല', 'ഊ', 'ഇരിഉന്നു', 'ഉന്ന', 'ച്ചുഇട്ട്', 'യൂ', 'ഞ്ഞുഏയ്ക്കാം', 'ഉന്നഉ്', 'ഉന്നു', 'ച്ചു', 'യാന്\u200d', '\u200dഞ്ഞ', 'ഉന്നഓടെ', 'യുമ്പോള്\u200d', 'ഉന്നുഉണ്ട്', 'ഞ്ഞപ്പോള്', 'ഉന്നഅര്', 'ഏണ്ട', 'ഞ്ഞ്', 'ആവുന്ന', 'യാത്ത', 'ച്ച്', 'ക്കാന്', 'പ്രോത്സാഹിപ്പിക്കാന്\u200d', 'ച്ചുഇരിഉന്നു', 'അണം', 'ഞ്ഞഇട്ട്', 'അട്ടെ', 'യുകയില്ല', 'ക്കുക', 'ആം'}
# ('കാണ്', 'k7')
# {'ഇച്ച', 'ആവ്ഉന്ന', 'ഉം', 'ഉമ്പോള്', 'ആഇ', 'ച്ച', 'ണ്ടുതുടങ്ങ്ഉം', 'ണ്ടു', 'ണ്ടുവര്ഉന്ന', 'ആറ്ഉണ്ട്', 'ുക', 'ണ്ട', 'ഇല്ല', 'ഊ', 'ാത്തതിനാല്', 'ാ൯', 'ണ്ട്അറിഉന്നഉ്', 'ാന്', 'ഉന്നുഇല്ല', 'ആറ്ഇല്ല', 'ആറ്', 'ഉന്നഉ്', 'ുവാന്\u200d', 'ഉന്നു', 'ണ്ടുഇട്ട്ഉണ്ട്', 'ണ്ടുവര്ഉന്നു', 'ട്ടു', 'ത്', 'ുമ്പോള്\u200d', 'ാന്\u200d', 'ഉന്നആഇ', 'ണ്ട്തുടങ്ങ്ഇ', 'ാനാകില്ല', 'ാതെ', 'ഉന്നുഉണ്ട്', 'ആറ്ആഇ', 'ഉന്നഅര്', 'ണ്ട്ഇരിഉന്നു', 'ഏണ്ട', 'ണ്ട്', 'ഉംആഇഇരിഉം', 'ണ്ട്അറിഞ്ഞ', 'ണ്ടുതുടങ്ങ്ഇരിഉന്നു', 'ഉംആഇഇരിഉന്നു', 'ത്ഇരിഉന്നു', 'ണ്ട്ഇട്ട്ഇല്ല', 'ഉന്നഇന്', 'ക', 'ആന്\u200d', 'ആം'}
# ('ചെയ്', 'k1')
# {'ആവ്ഉന്ന', 'ഇഇട്ട്', 'ഉന്നഎ', 'യുക', 'തുടങ്ങ്ഇരിഉന്നു', 'യാന്', 'ത്ഇഇരിഉന്നത്', 'ഉന്നടെ', 'ആന്ഉള്ള', 'യുമ്പോഴ്', 'ത്ഉണ്ട്', 'തത്', 'ഉന്ന', 'ആത്ത', 'ഉള്\u200d', 'ത്ഇരിഉന്നടെ', 'ട്ടു', 'യാൻ', 'ത്', 'യാന്\u200d', 'ത', 'തുഇരിഉന്ന', 'യാറുള്ളതു', 'ഏണ്ടിവര്ആണ്', 'ഉന്ന്', 'ത്ഇട്ട്ഉള്', 'ഉന്നുഉണ്ട്', 'ഏണ്ട', 'ആവുന്ന', 'യുന്പോള്\u200d', 'തിട്ട്', 'ത്ഇരിഉന്നു', 'ത്ഇഉണ്ട്', 'ത്ഇഇട്ട്ഇല്ല', 'തുഇരിഉന്നു', 'അണം', 'യപ്പെടും', 'യാ൯', 'ഉന്നഉ്ആല്', 'താല്', 'ത്ഇരിഉന്ന', 'ഉ്', 'ആറ്ഉണ്ട്', 'ഉന്നുഉള്ളൂ', 'തുവന്ന', 'ഇല്ല്', 'ഇട്ട്ഉള്', 'യുമോ', 'ത്ആല്', 'യുവാന്', 'തു', 'ആല്\u200d', 'ഉന്നഉ്', 'താല്\u200d', 'യുക\u200c', 'ഉന്നആഇ', 'യുകയും', 'തുതിര്ത്ത', 'തുകൊട്ഉന്ന', 'ത്കൊണ്ട്ഇരിഉന്നു', 'ത്ഇരി', 'യാത്ത', 'തുകഴിഞ്ഞു', 'യുമ്പോള്', 'ഉന്നഅര്ക്ക്', 'ഉം', 'ആന്\u200d', 'തുതാര്ക്ക്', 'ആം', 'ഉക'}
# ('ചെയ്', 'k2')
# {'ആവ്ഉന്ന', 'ഇഇട്ട്', 'ഉന്നഎ', 'തുടങ്ങ്ഇരിഉന്നു', 'യാന്', 'ത്ഇഇരിഉന്നത്', 'ഉന്നടെ', 'ആന്ഉള്ള', 'യുമ്പോഴ്', 'ത്ഉണ്ട്', 'തത്', 'ഉന്ന', 'ആത്ത', 'ഉള്\u200d', 'ത്ഇരിഉന്നടെ', 'ഉന്നു', 'ട്ടു', 'യാൻ', 'ത്', 'യാന്\u200d', 'ത', 'തുഇരിഉന്ന', 'യാറുള്ളതു', 'ഏണ്ടിവര്ആണ്', 'ഉന്ന്', 'ത്ഇട്ട്ഉള്', 'ഉന്നുഉണ്ട്', 'ഏണ്ട', 'ആവുന്ന', 'യുന്പോള്\u200d', 'തിട്ട്', 'ത്ഇരിഉന്നു', 'ത്ഇഉണ്ട്', 'ത്ഇഇട്ട്ഇല്ല', 'തുഇരിഉന്നു', 'അണം', 'യപ്പെടും', 'യാ൯', 'ഉന്നഉ്ആല്', 'താല്', 'ത്ഇരിഉന്ന', 'ഉ്', 'ആറ്ഉണ്ട്', 'ഉന്നുഉള്ളൂ', 'തുവന്ന', 'ഇല്ല്', 'ഇട്ട്ഉള്', 'യുമോ', 'ത്ആല്', 'യുവാന്', 'തു', 'ആല്\u200d', 'ഉന്നഉ്', 'താല്\u200d', 'യുക\u200c', 'ഉന്നആഇ', 'യുകയും', 'തുതിര്ത്ത', 'തുകൊട്ഉന്ന', 'ത്കൊണ്ട്ഇരിഉന്നു', 'ത്ഇരി', 'യാത്ത', 'തുകഴിഞ്ഞു', 'യുമ്പോള്', 'ഉന്നഅര്ക്ക്', 'ഉം', 'ആന്\u200d', 'തുതാര്ക്ക്', 'ആം', 'ഉക'}
# ('ചെയ്', 'k4')
# {'ആവ്ഉന്ന', 'ഇഇട്ട്', 'ഉന്നഎ', 'യുക', 'തുടങ്ങ്ഇരിഉന്നു', 'യാന്', 'ത്ഇഇരിഉന്നത്', 'ഉന്നടെ', 'ആന്ഉള്ള', 'യുമ്പോഴ്', 'ത്ഉണ്ട്', 'തത്', 'ഉന്ന', 'ആത്ത', 'ഉള്\u200d', 'ത്ഇരിഉന്നടെ', 'ഉന്നു', 'ട്ടു', 'യാൻ', 'ത്', 'യാന്\u200d', 'ത', 'തുഇരിഉന്ന', 'യാറുള്ളതു', 'ഏണ്ടിവര്ആണ്', 'ഉന്ന്', 'ത്ഇട്ട്ഉള്', 'ഉന്നുഉണ്ട്', 'ഏണ്ട', 'ആവുന്ന', 'യുന്പോള്\u200d', 'തിട്ട്', 'ത്ഇരിഉന്നു', 'ത്ഇഉണ്ട്', 'ത്ഇഇട്ട്ഇല്ല', 'തുഇരിഉന്നു', 'അണം', 'യപ്പെടും', 'യാ൯', 'ഉന്നഉ്ആല്', 'താല്', 'ത്ഇരിഉന്ന', 'ഉ്', 'ആറ്ഉണ്ട്', 'ഉന്നുഉള്ളൂ', 'തുവന്ന', 'ഇല്ല്', 'ഇട്ട്ഉള്', 'യുമോ', 'ത്ആല്', 'യുവാന്', 'ആല്\u200d', 'ഉന്നഉ്', 'താല്\u200d', 'യുക\u200c', 'ഉന്നആഇ', 'യുകയും', 'തുതിര്ത്ത', 'തുകൊട്ഉന്ന', 'ത്കൊണ്ട്ഇരിഉന്നു', 'ത്ഇരി', 'യാത്ത', 'തുകഴിഞ്ഞു', 'യുമ്പോള്', 'ഉന്നഅര്ക്ക്', 'ഉം', 'ആന്\u200d', 'തുതാര്ക്ക്', 'ആം', 'ഉക'}
# ('ചെയ്', 'nmod')
# {'ഇഇട്ട്', 'ഉന്നഎ', 'യുക', 'താല്', 'ഉ്', 'തുടങ്ങ്ഇരിഉന്നു', 'ആറ്ഉണ്ട്', 'ത്ഇഇരിഉന്നത്', 'ആന്ഉള്ള', 'ഇട്ട്ഉള്', 'യുമോ', 'ഉന്നുഉള്ളൂ', 'യുമ്പോഴ്', 'ഇല്ല്', 'ത്ഉണ്ട്', 'തത്', 'യുവാന്', 'ഉള്\u200d', 'ത്ഇരിഉന്നടെ', 'ആല്\u200d', 'ആം', 'താല്\u200d', 'ട്ടു', 'യുക\u200c', 'യാൻ', 'യാന്\u200d', 'ഏണ്ടിവര്ആണ്', 'തുഇരിഉന്ന', 'ഉന്നആഇ', 'യാറുള്ളതു', 'ഉന്ന്', 'ത്ഇട്ട്ഉള്', 'ഉന്നുഉണ്ട്', 'തുകൊട്ഉന്ന', 'ത്കൊണ്ട്ഇരിഉന്നു', 'ഏണ്ട', 'ത്ഇരി', 'യുന്പോള്\u200d', 'തുകഴിഞ്ഞു', 'യുമ്പോള്', 'തിട്ട്', 'ത്ഇരിഉന്നു', 'ത്ഇഉണ്ട്', 'ത്ഇഇട്ട്ഇല്ല', 'തുഇരിഉന്നു', 'അണം', 'ഉം', 'യപ്പെടും', 'തുതാര്ക്ക്', 'യാ൯', 'ഉക', 'ഉന്നഉ്ആല്'}
# 19

# %%
# Iterate over each of the sentences and get nonce sentences, only for the given dependency types


sentences_dict = {}

traversed = {}

max_nonce = 10

incorrect_traversed = {}

nonce_dict = {}

def get_nonce(sid):
    
    if sid not in traversed:
        traversed[sid] = set()
    
    
    # Indices to words for each sentence (type: Int64Index([]))
    sentence_index = sentID_group_obj.groups[sid]
    sentence_df = df[df.index.isin(sentence_index)]
    
    index_list = []
    i = 0
    for index, row in sentence_df.iterrows():
        
        index_list.append(index)
        
        if row['DEPS'] not in set(deps_to_include):
            i +=1
            continue
        if row['vib'] == 'SAME':
            i +=1
            continue
        else:
            # Get possible replacements
            if row['DEPS'] not in nonce_dict:
                nonce_dict[row['DEPS']] = set()
            replacements = lemma_dep_to_vib[(row['lemma'], row['DEPS'])]
            if len(replacements) == 0:
                continue
            eligible_df= df[(df['lemma'] == row['lemma']) & (df['vib'].isin(list(replacements)))]
            nonce_dict[str(row['DEPS'])].add((sid, index, row['Unnamed: 0'], i, str(list(eligible_df['Unnamed: 0']))))
    
        i +=1
for sid in sent_ids[:1000]:
    if sid not in sentences_dict:
        sentences_dict[sid] = []
    get_nonce(sid)

nonce_count_dict = {}
count = 0
for key, val in nonce_dict.items():
    nonce_count_dict[key] = len(val)
    count += len(val)
nonce_count_dict
# Out:
# {'k7': 318,
#  'k4': 197,
#  'vmod': 580,
#  'r6': 279,
#  'k5': 47,
#  'nmod': 401,
#  'k1': 236,
#  'k2': 218,
#  'k3': 7}

# %%
nonce_deps_sents_dict = {}
for key, val in nonce_dict.items():
    for v in list(val):
        if len(v) == 0:
            continue
        sid = v[0]
        index = v[1]
        unnamed_index = v[2]
        index_i = v[3]
        index_to_replace = int(v[4][1:-1].split(',')[0])
        sentence_index = sentID_group_obj.groups[sid]
        text = list(df[df.index.isin(sentence_index)]['word'])
        nonce_text = text.copy()
        nonce_text[index_i] = list(df[df['Unnamed: 0'] == index_to_replace]['word'])[0]
        if key not in nonce_deps_sents_dict:
            nonce_deps_sents_dict[key] = []
        nonce_deps_sents_dict[key].append((text, nonce_text, sid, index, unnamed_index, index_i, index_to_replace))

# %%
nonce_deps_sents_dict['k3']
# Out:
# [(['മൂന്നാറിലെ',
#    'തമിഴ്\u200cവംശജരെ',
#    'കേരള',
#    'സമൂഹത്തോട്',
#    'ഒരുമിപ്പിക്കുന്നതില്\u200d',
#    'കഴിഞ്ഞ',
#    'ഒരു',
#    'നൂറ്റാണ്ടില്\u200d',
#    'നമുക്ക്',
#    'ഉണ്ടായ',
#    'പരാജയം',
#    'ആണ്',
#    'രണ്ടാമത്തേത്'],
#   ['മൂന്നാറിലെ',
#    'തമിഴ്\u200cവംശജരെ',
#    'കേരള',
#    'സമൂഹത്തെ',
#    'ഒരുമിപ്പിക്കുന്നതില്\u200d',
#    'കഴിഞ്ഞ',
#    'ഒരു',
#    'നൂറ്റാണ്ടില്\u200d',
#    'നമുക്ക്',
#    'ഉണ്ടായ',
#    'പരാജയം',
#    'ആണ്',
#    'രണ്ടാമത്തേത്'],
#   'malayalam/final data - validated/03-06-2017/tourism/Depn/Munnar_2.depn.ssf:15',
#   53312,
#   74483,
#   3,
#   4590),
#  (['അവനോട്',
#    'പുകവലി',
#    'നിറുത്താന്\u200d',
#    'ഡോക്ടര്\u200d',
#    'നിര്\u200dദേശ്ശിച്ചു'],
#   ['അവര്\u200dക്ക്',
#    'പുകവലി',
#    'നിറുത്താന്\u200d',
#    'ഡോക്ടര്\u200d',
#    'നിര്\u200dദേശ്ശിച്ചു'],
#   'malayalam/final data - validated/03-06-2017/general/Depn/RawText_6.depn.ssf:44',
#   50332,
#   70818,
#   0,
#   54),
#  (['ദമനിലെ',
#    'പള്ളികളില്\u200d',
#    'ചുമരുകളില്\u200d',
#    'തടിയില്\u200d',
#    'തീര്\u200dത്തിട്ട്',
#    'ഉള്ള',
#    'യേശുക്രിസ്തുവിന്\u200dറെ',
#    'കഴിഞ്ഞകാല',
#    'ജീവിതത്തെ',
#    'കുറിച്ച്',
#    'ഉള്ള',
#    'കൊത്തുപണികളാല്\u200d',
#    'സന്ദര്\u200dശകര്\u200d',
#    'ഇവിടേക്ക്',
#    'ആകര്\u200dഷിക്കപ്പെടുന്നു'],
#   ['ദമനിലെ',
#    'പള്ളികളില്\u200d',
#    'ചുമരുകളില്\u200d',
#    'തടിയില്\u200d',
#    'തീര്\u200dത്തിട്ട്',
#    'ഉള്ള',
#    'യേശുക്രിസ്തുവിന്\u200dറെ',
#    'കൊത്തുപണികള്\u200d',
#    'ജീവിതത്തെ',
#    'കുറിച്ച്',
#    'ഉള്ള',
#    'കൊത്തുപണികളാല്\u200d',
#    'സന്ദര്\u200dശകര്\u200d',
#    'ഇവിടേക്ക്',
#    'ആകര്\u200dഷിക്കപ്പെടുന്നു'],
#   'malayalam/final data - validated/11-05-2017/tourism (parallel)/Depn/Mal_tourism 1.depn.ssf:333',
#   41610,
#   59851,
#   7,
#   20078),
#  (['ഘാണ്ഡവി',
#    'വനത്തില്\u200d',
#    'ഭഗവാന്\u200d\u200d',
#    'പരശുരാമനാല്\u200d',
#    'സ്ഥാപിതം',
#    'ആയ',
#    'ശിവവല്ലഭപുരം',
#    'എന്ന',
#    'സ്ഥലത്ത്',
#    'മുക്തേശ്വര്\u200d',
#    'മഹാദേവന്\u200dറെ',
#    'യാഗപൂജ',
#    'അല്ലങ്കില്\u200d',
#    'പരിപാവനമായ',
#    'ഗംഗാനദിയില്\u200d',
#    'സ്നാനം',
#    'ചെയ്യുക',
#    'കൂടാതെ',
#    'അവിടെ',
#    'പിണ്ഡദാനം',
#    'ചെയ്യുകയും',
#    'വഴി',
#    'എല്ലാ',
#    'ശുദ്ധികര്\u200dമ്മങ്ങളും',
#    'പൂര്\u200dത്തി',
#    'ആകും'],
#   ['ഘാണ്ഡവി',
#    'വനത്തില്\u200d',
#    'ഭഗവാന്\u200d\u200d',
#    'പരശുരാമനും',
#    'സ്ഥാപിതം',
#    'ആയ',
#    'ശിവവല്ലഭപുരം',
#    'എന്ന',
#    'സ്ഥലത്ത്',
#    'മുക്തേശ്വര്\u200d',
#    'മഹാദേവന്\u200dറെ',
#    'യാഗപൂജ',
#    'അല്ലങ്കില്\u200d',
#    'പരിപാവനമായ',
#    'ഗംഗാനദിയില്\u200d',
#    'സ്നാനം',
#    'ചെയ്യുക',
#    'കൂടാതെ',
#    'അവിടെ',
#    'പിണ്ഡദാനം',
#    'ചെയ്യുകയും',
#    'വഴി',
#    'എല്ലാ',
#    'ശുദ്ധികര്\u200dമ്മങ്ങളും',
#    'പൂര്\u200dത്തി',
#    'ആകും'],
#   'malayalam/final data - validated/11-05-2017/tourism (parallel)/Depn/Mal_tourism 1.depn.ssf:45',
#   40676,
#   58763,
#   3,
#   1657),
#  (['ചുറ്റുപാടുമുള്ള',
#    'പ്രദേശങ്ങളേക്കാൾ',
#    'വളരെ',
#    'ഉയർന്ന',
#    'ഭൂവിഭാഗം',
#    'ആണ്',
#    'പർവ്വതം',
#    'എന്ന്',
#    'അറിയപ്പെടുന്നത്'],
#   ['ചുറ്റുപാടുമുള്ള',
#    'പ്രദേശത്തിലെ',
#    'വളരെ',
#    'ഉയർന്ന',
#    'ഭൂവിഭാഗം',
#    'ആണ്',
#    'പർവ്വതം',
#    'എന്ന്',
#    'അറിയപ്പെടുന്നത്'],
#   'malayalam/final data - validated/03-06-2017/general/Depn/General_Corpus7.depn.ssf:41',
#   48919,
#   69102,
#   1,
#   333),
#  (['മനുഷ്യരെക്കാളും', 'മൃഗങ്ങള്\u200dക്ക്', 'ആണ്', 'സ്നേഹം', 'ഉള്ളത്'],
#   ['മനുഷ്യരുടെ', 'മൃഗങ്ങള്\u200dക്ക്', 'ആണ്', 'സ്നേഹം', 'ഉള്ളത്'],
#   'malayalam/final data - validated/03-06-2017/general/Depn/RawText_6.depn.ssf:20',
#   50240,
#   70710,
#   0,
#   63630),
#  (['ഈ',
#    'ക്ഷേത്രം',
#    'ആര്\u200dക്കിയോളജി',
#    'വിഭാഗത്താല്\u200d',
#    'സംരക്ഷിക്കപ്പെട്ടിരിക്കുന്ന',
#    'സ്മാരകം',
#    'ആണ്'],
#   ['ഈ',
#    'ക്ഷേത്രം',
#    'ആര്\u200dക്കിയോളജി',
#    'വിഭാഗങ്ങള്\u200d',
#    'സംരക്ഷിക്കപ്പെട്ടിരിക്കുന്ന',
#    'സ്മാരകം',
#    'ആണ്'],
#   'malayalam/final data - validated/11-05-2017/tourism (parallel)/Depn/Mal_tourism 1.depn.ssf:246',
#   41255,
#   59453,
#   3,
#   7228)]

# %%
cols = ['word', 'lemma', 'DEPS', 'vib', 'Unnamed: 0']
df[df['sentID'] == 'malayalam/final data - validated/11-05-2017/tourism (parallel)/Depn/Mal_tourism 1.depn.ssf:246'][cols]
# Out:
#                        word             lemma  DEPS     vib  Unnamed: 0
# 41599                ദമനിലെ               ദമന    r6     ഇലെ       59840
# 41600           പള്ളികളില്‍             പള്ളി    k7  കള്ഇല്       59841
# 41601           ചുമരുകളില്‍             ചുമരു    k7  കള്ഇല്       59842
# 41602              തടിയില്‍               തടി    k7     ഇല്       59843
# 41603         തീര്‍ത്തിട്ട്          തീര്‍ത്ത  vmod   ഇട്ട്       59844
# 41604                  ഉള്ള               ഉള്  nmod       ള       59845
# 41605   യേശുക്രിസ്തുവിന്‍റെ      യേശുക്രിസ്തു    r6      ടെ       59846
# 41606             കഴിഞ്ഞകാല         കഴിഞ്ഞകാല    k2    SAME       59847
# 41607             ജീവിതത്തെ             ജീവിത    k2       എ       59848
# 41608              കുറിച്ച്          കുറിച്ച്    k2    SAME       59849
# 41609                  ഉള്ള               ഉള്  nmod       ള       59850
# 41610       കൊത്തുപണികളാല്‍         കൊത്തുപണി    k3  കള്ആല്       59851
# 41611          സന്ദര്‍ശകര്‍       സന്ദര്‍ശകന്    k1    അര്‍       59852
# 41612             ഇവിടേക്ക്             ഇവിടെ    k7   േക്ക്       59853
# 41613  ആകര്‍ഷിക്കപ്പെടുന്നു  ആകര്‍ഷിക്കപ്പെട്  root   ഉന്നു       59854

# %%
df[(df['Unnamed: 0'] == 59453) | (df['Unnamed: 0'] == 7228)]
# Out:
#        Unnamed: 0  Unnamed: 0.1  \
# 5307         7228          7228
# 41255       59453         59453
#
#                                                   sentID  wordPosition  \
# 5307   malayalam/full data as on 25-01-2017/not valid...             4
# 41255  malayalam/final data - validated/11-05-2017/to...             2
#
#                word  lemma   UPOS XPOS  \
# 5307    വിഭാഗങ്ങള്‍  വിഭാഗ   N_NN    _
# 41255  വിഭാഗത്താല്‍  വിഭാഗ  N__NN    _
#
#                                                    FEATS  HEAD  ...    tam  \
# 5307   category=n|gender=ne|number=pl|person=3|case=d...     5  ...  NgaLu
# 41255  category=n|gender=ne|number=sg|person=3|case=d...     3  ...   ttAl
#
#       source        target          common deleted sourceSkeleton  \
# 5307   വിഭാഗ   വിഭാഗങ്ങള്‍  {1: 'വിഭാഗ#1'}   ['ϵ']            #1#
# 41255  വിഭാഗ  വിഭാഗത്താല്‍  {1: 'വിഭാഗ#1'}   ['ϵ']            #1#
#
#       targetSkeleton             added            aligned extracted
# 5307       !1!ങ്ങള്‍   ['ങ്ങള്\u200d']   വിഭാഗINS(ങ്ങള്‍)    ങ്ങള്‍
# 41255     !1!ത്താല്‍  ['ത്താല്\u200d']  വിഭാഗINS(ത്താല്‍)   ത്താല്‍
#
# [2 rows x 29 columns]

# %%
# Save 10 examples of each dependency type 

nonce_deps_sents_dict

fp = open('Nonce_examples.txt', 'w')

n_save = 10

for key, val in nonce_deps_sents_dict.items():
    count = 0
    fp.write(str(key) + "\n\n")
    for v in val:
        fp.write(str(v[2]) + "\t" + str(v[5]) + "\t" + " ".join(v[0]) + "\t" + " ".join(v[1]) + "\n")
        count +=1
        if count >= n_save:
            fp.write("\n\n")
            break
fp.close()
